# %% [markdown]
# # IPython / Jupyter
#
# ### Min Ragan-Kelley, UC Berkeley
#
# ### [bit.ly/ososrk](http://bit.ly/ososrk)
#
# <img src="jupyter.png" width=300>
# ![ipython](ipython.png)

# %% [markdown]
# # What we do

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import seaborn

# %%
for i in range(4):
    plt.plot(np.cumsum(np.random.random(1000) - 0.5))

# %% [markdown]
# # $M\alpha\tau\hbar!$
#
# \begin{align}
# \dot{x} & = \sigma(y-x) \\
# \dot{y} & = \rho x - y - xz \\
# \dot{z} & = -\beta z + xy
# \end{align}

# %% [markdown]
# - language agnostic (R, Julia, Haskell, Spark, Javascript, Perl, Matlab, Scala, > 30 kernels)
# - open, pulic, simple JSON format
# - shareable via [nbviewer](http://nbviewer.org)
# - exportable to html, latex, pdf, rst, markdown, custom formats

# %% [markdown]
# # What we've done

# %% [markdown]
# ## Paper
#
# Computational companion (ISME): [doi:0.1038/ismej.2012.123](http://www.nature.com/ismej/journal/v7/n3/full/ismej2012123a.html)
#
# ## Books
#
# [<img src="python-signal.png" width=400>](http://nbviewer.ipython.org/github/unpingco/Python-for-Signal-Processing/)
#
# [<img src="mining-slice.png" width=400>](http://nbviewer.ipython.org/github/ptwobrussell/Mining-the-Social-Web-2nd-Edition/tree/master/ipynb)
#
# [<img src="bayesian.png" width=400>](http://nbviewer.ipython.org/github/CamDavidsonPilon/Probabilistic-Programming-and-Bayesian-Methods-for-Hackers/blob/master/Chapter1_Introduction/Chapter1.ipynb)
#
# ## More: [bit.ly/nbpapers](http://bit.ly/nbpapers)

# %% [markdown]
# # Where we are heading
#
# - integration into publishing pipeline (books, papers, blogging, etc.)
# - tools for collaboration
#   - improve diff/merge for VCS-based collab
#   - live collaboration

# %%
# %%html
# <style type='text/css'>
# h1, h2, h3 {
#   text-align: center;
# }
# </style>
# Out:
# <style type='text/css'>
# h1, h2, h3 {
#   text-align: center
# }
